# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('mtcars.csv')

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Find the car with the best mpg

# %%
best_mpg=df['mpg'].max()
print(best_mpg)
# Out:
# 33.9

# %%
#Find the car with the worst mpg

# %%
worst_mpg=df['mpg'].min()
print(worst_mpg)
# Out:
# 10.4

# %%
#Find the car with the best horsepower

# %%
best_hp=df['hp'].max()
print(best_hp)
# Out:
# 335

# %%
# Find 5 number summary of displacement

# %%
df.describe().loc[['min','25%','50%','75%','max']]
# Out:
#         mpg  cyl     disp     hp   drat       wt     qsec   vs   am  gear  \
# min  10.400  4.0   71.100   52.0  2.760  1.51300  14.5000  0.0  0.0   3.0
# 25%  15.425  4.0  120.825   96.5  3.080  2.58125  16.8925  0.0  0.0   3.0
# 50%  19.200  6.0  196.300  123.0  3.695  3.32500  17.7100  0.0  0.0   4.0
# 75%  22.800  8.0  326.000  180.0  3.920  3.61000  18.9000  1.0  1.0   4.0
# max  33.900  8.0  472.000  335.0  4.930  5.42400  22.9000  1.0  1.0   5.0
#
#      carb
# min   1.0
# 25%   2.0
# 50%   2.0
# 75%   4.0
# max   8.0

# %%
#Find median horse power

# %%
med_hp=df['hp'].median()
print(med_hp)
# Out:
# 123.0

# %%
#What is average mpg for manual vs. automatic cars

# %%
df.loc[0].compare(df.loc[2])
# Out:
#             self       other
# model  Mazda RX4  Datsun 710
# mpg         21.0        22.8
# cyl            6           4
# disp       160.0       108.0
# hp           110          93
# drat         3.9        3.85
# wt          2.62        2.32
# qsec       16.46       18.61
# vs             0           1
# carb           4           1

# %%
#Draw a histogram of miles per gallon

# %%
plt.hist(df['mpg'],edgecolor='black',bins=6)
plt.xlabel('Miles per gallon')
plt.ylabel('Frequency')
plt.title('Basic Histogram')
plt.show()

# %%
#Boxplot of mpg for each cylinder type

# %%
sns.boxplot(x=df["cyl"],y=df["mpg"])
plt.show()

# %%
#Create a crosstab displaying count of automatic vs. manual cars

# %%
crosstab = pd.crosstab(df.am, df.cyl)
print(crosstab)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
# Create a crosstab displaying count of “am vs cyl”

# %%
correlation = df['calories'].corr(df[''])
print(correlation)
# Out:
# -0.8676593765172281

# %%
#exercise2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('bollywood.csv')

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
print(df.count())
# Out:
# SlNo                   149
# Release Date           149
# MovieName              149
# ReleaseTime            149
# Genre                  149
# Budget                 149
# BoxOfficeCollection    149
# YoutubeViews           149
# YoutubeLikes           149
# YoutubeDislikes        149
# dtype: int64

# %%
genre_counts = df['Genre'].str.split('|').explode().value_counts()
genre_counts_df = genre_counts.reset_index()
genre_counts_df.columns = ['Genre', 'Count']
genre_counts_df = genre_counts_df.sort_values(by='Count', ascending=False)

print(genre_counts_df)
# Out:
#        Genre  Count
# 0     Comedy     36
# 1     Drama      35
# 2   Thriller     26
# 3    Romance     25
# 4     Action     21
# 5  Thriller       3
# 6    Action       3

# %%
top_genre = genre_counts_df.iloc[0]
print(f"The genre with the highest number of releases is {top_genre['Genre']} with {top_genre['Count']} releases.")
# Out:
# The genre with the highest number of releases is Comedy with 36 releases.

# %%
df['Genre'] = df['Genre'].str.split('|')
df = df.explode('Genre')
cross_tab = pd.crosstab(df['Genre'], df['ReleaseTime'])

print(cross_tab)
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'])
df['month'] = df['Release Date'].dt.month
month_counts = df['month'].value_counts().sort_index()
print(month_counts)
# Out:
# 1     20
# 2     16
# 3     19
# 4     11
# 5     18
# 6     10
# 7     16
# 8      8
# 9     10
# 10     9
# 11    10
# 12     2
# Name: month, dtype: int64

# %%
df['Release Date'] = pd.to_datetime(df['Release Date'])
high_budget_df = df[df['Budget'] >= 25]
high_budget_df['month'] = high_budget_df['Release Date'].dt.month
month_counts = high_budget_df['month'].value_counts()
top_month = month_counts.idxmax()
top_month_count = month_counts.max()
print(top_month)
# Out:
# 2
# C:\Users\mca\AppData\Local\Temp\ipykernel_5816\3679554339.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   high_budget_df['month'] = high_budget_df['Release Date'].dt.month

# %%
df['ROI'] = (df['BoxOfficeCollection'] - df['Budget']) / df['Budget']
df_sorted = df.sort_values(by='ROI', ascending=False)
top_10_movies = df_sorted.head(10)
print(top_10_movies['MovieName'].tolist())
# Out:
# ['Aashiqui 2', 'PK', 'Grand Masti', 'The Lunchbox', 'Fukrey', 'Mary Kom', 'Shahid', 'Humpty Sharma Ki Dulhania', 'Bhaag Milkha Bhaag', 'Chennai Express']

# %%
correlation =df['BoxOfficeCollection'].corr(df['YoutubeLikes'])
print(correlation)
# Out:
# 0.6825165877731297

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Genre', y='YoutubeLikes', data=df)
plt.xlabel('Genre')
plt.ylabel('YouTubeLikes')
plt.title('YouTube Likes by Movie Genre')
plt.xticks(rotation=45)
plt.show()

# %%
correlation_matrix = df.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='BoxOfficeCollection', y='Genre', data=df)
plt.title('Box Office Collection by Genre (2013-2015)')
plt.xlabel('Box Office Collection (in Crores)')
plt.ylabel('Genre')
plt.show()
